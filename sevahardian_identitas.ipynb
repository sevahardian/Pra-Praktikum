# %% [markdown]
# <a href="https://colab.research.google.com/github/sevahardian/Pra-Praktikum/blob/main/sevahardian_identitas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Nama saya adalah Muhammad Seva Hardian") #Menampilkan nama lengkap saya
print("NIM saya yaitu", 2605060046) #Menampilkan NIM saya
print("Tempat tanggal lahir saya adalah Magelang,", 17, "Juli", 2008) #Menampilkan tempat tanggal lahir saya
print("Alamat saya ada di Kabupaten Secang, Magelang") #Menampilkan alamat rumah saya
print("Jenis Kelamin saya adalah Laki-laki") #Menampilkan jenis kelamin saya
print("Hobi saya yaitu Membaca komik digital") #Menampilkan hobi saya
# Out:
# Nama saya adalah Muhammad Seva Hardian
# NIM saya yaitu 2605060046
# Tempat tanggal lahir saya adalah Magelang, 17 Juli 2008
# Alamat saya ada di Kabupaten Secang, Magelang
# Jenis Kelamin saya adalah Laki-laki
# Hobi saya yaitu Membaca komik digital

# %%
#Ini adalah komentar

# %%
"""
Ini
adalah
komentar
banyak baris
"""
print("Ini adalah komentar banyak baris")
# Out:
# Ini adalah komentar banyak baris

# %%
print("Ini adalah tipe data string")
# Out:
# Ini adalah tipe data string

# %%
print(123456789) #Ini adalah tipe data integer
# Out:
# 123456789
