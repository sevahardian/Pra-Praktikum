# %%
print("Muhammad Seva Hardian") #Menampilkan/Nge-print nama lengkap saya
print(2605060046) #Menampilkan/Nge-print NIM saya
print("Magelang, 17 Juli 2008") #Menampilkan/Nge-print tempat tanggal lahir saya
print("Secang, Magelang") #Menampilkan/Nge-print alamat rumah saya
print("Laki-laki") #Menampilkan/Nge-print jenis kelamin saya
print("Membaca komik digital") #Menampilkan/Nge-print hobi saya
# Out:
# Muhammad Seva Hardian
# 2605060046
# Magelang, 17 Juli 2008
# Secang, Magelang
# Laki-laki
# Membaca komik digital
